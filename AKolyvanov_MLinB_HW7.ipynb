# %% [markdown]
# ### Домашнее задание к уроку 7.

# %% [raw]
# - взять любой набор данных для бинарной классификации;
# - сделать обзорный анализ выбранного датасета;
# - сделать feature engineering;
# - обучить любой классификатор (какой вам нравится);
# - разобраться с SHAP и построить важности признаков для:
#     всего тестового набора данных (summary_plot - дать интерпретацию);
#     для топ 10%;
# - для отдельных наблюдений вывести force_plot и попытаться проинтерпретировать результат.

# %%
import shap
import xgboost as xgb
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline, make_pipeline, FeatureUnion
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, r2_score

# %% [raw]
# Выполним интерпретацию на примере датасета "Прогнозирование цен на жилье в Бостоне.
# Характеристики домов:
# CRIM  – уровень преступности
# ZN    – доля земель под жилую застройку
# INDUS – доля акров, не связанных с розничной торговлей в расчете на город
# CHAS  – 1, если граничит с рекой
# NOX   – концентрация оксида азота
# RM    – среднее количество комнат на дом
# AGE   – доля жилых домов, построенных до 1940 года
# DIS   – взвешенные расстояния до пяти бостонских центров занятости
# RAD   – индекс доступности магистралей
# TAX   – полная ставка налога на имущество
# PTRATIO – соотношение учеников и учителей по городам
# B     – доля лиц афроамериканского происхождения
# LSTAT – процент населения с более низким статусом
# y     – медианная стоимость домов (в тыс. долларов)

# %%
X, y = shap.datasets.boston()
X.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT
# 0     15.3  396.90   4.98
# 1     17.8  396.90   9.14
# 2     17.8  392.83   4.03
# 3     18.7  394.63   2.94
# 4     18.7  396.90   5.33

# %%
X.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %%
y
# Out:
# array([24. , 21.6, 34.7, 33.4, 36.2, 28.7, 22.9, 27.1, 16.5, 18.9, 15. ,
#        18.9, 21.7, 20.4, 18.2, 19.9, 23.1, 17.5, 20.2, 18.2, 13.6, 19.6,
#        15.2, 14.5, 15.6, 13.9, 16.6, 14.8, 18.4, 21. , 12.7, 14.5, 13.2,
#        13.1, 13.5, 18.9, 20. , 21. , 24.7, 30.8, 34.9, 26.6, 25.3, 24.7,
#        21.2, 19.3, 20. , 16.6, 14.4, 19.4, 19.7, 20.5, 25. , 23.4, 18.9,
#        35.4, 24.7, 31.6, 23.3, 19.6, 18.7, 16. , 22.2, 25. , 33. , 23.5,
#        19.4, 22. , 17.4, 20.9, 24.2, 21.7, 22.8, 23.4, 24.1, 21.4, 20. ,
#        20.8, 21.2, 20.3, 28. , 23.9, 24.8, 22.9, 23.9, 26.6, 22.5, 22.2,
#        23.6, 28.7, 22.6, 22. , 22.9, 25. , 20.6, 28.4, 21.4, 38.7, 43.8,
#        33.2, 27.5, 26.5, 18.6, 19.3, 20.1, 19.5, 19.5, 20.4, 19.8, 19.4,
#        21.7, 22.8, 18.8, 18.7, 18.5, 18.3, 21.2, 19.2, 20.4, 19.3, 22. ,
#        20.3, 20.5, 17.3, 18.8, 21.4, 15.7, 16.2, 18. , 14.3, 19.2, 19.6,
#        23. , 18.4, 15.6, 18.1, 17.4, 17.1, 13.3, 17.8, 14. , 14.4, 13.4,
# ...

# %%
# создадим и обучим модель с использованием градиентного бустинга
model = xgb.train(params = {"learning_rate": 0.01}, dtrain = xgb.DMatrix(X, label=y), num_boost_round = 100)

# %%
# Создадим объясняющий объект и передадим ему созданную и обученную модель
explainer = shap.TreeExplainer(model)

# %%
# Расчет значения Шепли для всего датасета
shap_values = explainer.shap_values(X)

# %%
# load JS visualization code to notebook
shap.initjs()
# Получить локальные объяснения для первого (0) наблюдения в датасете
shap.force_plot(explainer.expected_value, shap_values[0,:], X.iloc[0,:])
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,
# ...

# %%
# для всех наблюдений в датасете:
shap.force_plot(explainer.expected_value, shap_values, features=X)
# Out:
# <div id='iADSH8ILZDELJ4IW8FPC5'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
# ...

# %%
# для 250 наблюдений
shap.force_plot(explainer.expected_value, shap_values[:250,:], X.iloc[:250,:])
# Out:
# <div id='iP4CURCYB4FDOM3QSK3MW'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
# ...

# %%
# для совсем всех, еще изменяем размер графика
shap.summary_plot(shap_values, X, plot_size=(20,9))

# %%
# Значение признаков в виде барчарта:
shap.summary_plot(shap_values, X, plot_type="bar", plot_size=(10,6))

# %% [markdown]
# Как показывают графики, наиболее важные признаки: RM и LSTAT

# %%
# Взаимодействия между признакми RM и LSTAT
shap.dependence_plot("RM", shap_values, X, interaction_index='LSTAT')

# %% [raw]
# Среднее число комнат в доме имеет чуть меньшее влияние на цену дома при высоких значениях процента населения с более низким статусом

# %%
# Графики взаимодействия всех признаков
for feature_name in X.columns:
    shap.dependence_plot(feature_name, shap_values, X, display_features=X)
